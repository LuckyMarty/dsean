# %%
# !pip3 install html5lib
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: html5lib in /usr/local/lib/python3.9/site-packages (1.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.9/site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/site-packages (from html5lib) (0.5.1)
# WARNING: You are using pip version 21.3.1; however, version 24.0 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import requests
import pandas as pd

url = "https://www.picard.fr/rayons/legumes-et-fruits?start=28&sz=28"


r = requests.get(url)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text)

# %%
soup.find_all("div", class_="pi-ProductCard")
# Out:
# [<div class="pi-ProductCard js-ProductCard">
#  <a class="pi-ProductCard-link js-gtm-ProductCard-link" href="/produits/potage-legumes-verts-000000000000013659.html">
#  <div class="pi-ProductCard-topContainer js-ProductCard-topContainer">
#  <div class="pi-ProductCardTag-placeholder">
#  <style>
#  .pi-ProductCard--4f573d46ee21a30fdb83ba9043 {
#  color: #e94f5e;
#  }
#  .pi-ProductCard--4f573d46ee21a30fdb83ba9043:before {
#  background-color: #e94f5e;
#  }
#  .pi-ProductCard--4f573d46ee21a30fdb83ba9043:after {
#  border-color: #e94f5e transparent transparent #e94f5e;
#  }
#  </style>
#  <div class="pi-ProductCardTag pi-ProductCardTag--card pi-ProductCard--4f573d46ee21a30fdb83ba9043 js-ProductCardTag">
#  <svg aria-hidden="true" class="u-Icon pi-ProductCardTag-icon" focusable="false" height="60" viewbox="0 0 60 60" width="60">
#  <use href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#fidelity-offer" xlink:href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#fidelity-offer"></use>
#  </svg>
#  <div class="pi-ProductCardTag-title">
#  -0,35€ avec la carte
#  </div>
#  <button class="pi-ProductCardTag-overlayArrow">
#  <svg aria-hidden="true" class="u-Icon pi-ProductCardTag-overlayArrowIcon" focusable="false" height="9" viewbox="0 0 16 9" width="16">
#  <use href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#arrow" xlink:href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#arrow"></use>
#  </svg>
#  </button>
#  <div class="pi-ProductCardTag-overlay pi-ProductCardTag-overlay">
#  Du 05 février au 03 mars 2024, bénéficiez de réduction sur une sélection de produits avec la carte Picard&amp;Nous.
#  </div>
#  </div>
#  </div>
#  <div class="pi-ProductCard-imageContainer">
#  <img alt="POTAGE LEGUMES VERTS 1KG" class="pi-ProductCard-image pi-ProductCard-imageHover lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dwc9b16ea2/produits/edition/13659.png?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  <img alt="POTAGE LEGUMES VERTS 1KG" class="pi-ProductCard-image pi-ProductCard-imageInitial lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dwa2d9a088/produits/000000000000013659_P.png?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  </div>
#  </div>
#  <div class="pi-ProductCard-bottomContainer">
#  <div class="pi-ProductCard-labelWrapper">
#  </div>
#  <div class="pi-ProductCard-reviewWrapper">
#  <div class="pi-Rating null">
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <span class="pi-Rating-rate" style="width:91.96199999999999%;background-image: url('/on/demandware.static/Sites-picard-Site/-/default/dw5a2139ce/assets/images/reviews/star-full.png')"></span>
#  <span class="sr-only">4.5981 sur 5</span>
#  </div>
#  </div>
#  <h3 class="pi-ProductCard-name">
#  Potage de légumes verts
#  </h3>
#  <div class="pi-ProductCard-weight">
#  <span>le sachet de 1 kg</span>
#  </div>
#  <div class="pi-ProductCardPrice pi-ProductCardPrice--fid">
#  <div class="pi-ProductCardPrice-block">
#  <div class="pi-ProductCardPrice-kiloPrice">
#  <span class="sr-only">Prix au kilo</span>
#  3,50 €/kg
#  </div>
#  <div class="pi-ProductCardPrice-salesPrice">
#  <span class="sr-only">Prix soldé</span>
#  3,50 €
#  </div>
#  </div>
#  <div class="pi-ProductCardPrice-block pi-ProductCardPrice-block--fidelite">
#  <style type="text/css">
#  .pi-ProductOffer-pricee94f5e {
#  color: #e94f5e;
#  }
#  </style>
#  <div class="pi-ProductCardPrice-kiloPrice pi-ProductOffer-pricee94f5e">
#  <span class="sr-only">Prix au kilo carte fidélité</span>
#  3,15 €/kg
#  </div>
#  <div class="pi-ProductCardPrice-salesPrice pi-ProductOffer-pricee94f5e">
#  <span class="sr-only">Prix soldé carte fidélité</span>
#  3,15 €
#  </div>
#  <div class="pi-ProductCardPrice-standardPrice">
#  <span class="sr-only">Prix soldé carte fidélité</span>
#  prix carte
#  </div>
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="pi-ProductCard-actions">
#  <form action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-AddToCartProduct" class="pi-AddToCart js-AddToCart" data-delete-action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-DeleteProductLineItem" data-icon-msg="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#check" data-icon-tooltip="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#close" data-pid="000000000000013659" data-show-msg="false" data-text-msg="dans votre panier !" data-text-tooltip="La quantité maximale est atteinte sur ce produit." id="dwfrm_product_addtocart_d0fmlrrzqzxs" method="post">
#  <input name="cartAction" type="hidden" value="add"/>
#  <input class="js-AddToCart-pid" name="pid" type="hidden" value="000000000000013659"/>
#  <input name="sourcePage" type="hidden" value="null"/>
#  <button class="pi-AddToCart-button pi-ProductCard-btn pi-ProductCard-btn--blue u-Button js-AddToCart-button" data-isdisabled="false" data-showqty="" disabled="">
#  Ajouter au panier
#  <svg aria-hidden="true" class="u-Icon u-Button-icon" focusable="false" height="25" viewbox="0 0 31 25" width="31">
#  <use href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket" xlink:href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket"></use>
#  </svg>
#  </button>
#  <div class="pi-Quantity js-Quantity pi-AddToCart-quantity null" data-pid="000000000000013659">
#  <button class="pi-Quantity-button js-Quantity-less" data-id="less-000000000000013659" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="3" viewbox="0 0 14.5 1.5" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M.8 1.5c-.4 0-.8-.3-.8-.8s.3-.8.8-.8h13c.4 0 .8.3.8.8s-.3.8-.8.8H.8z"></path>
#  </svg>
#  <span class="sr-only">
#  Retirer 1 quantité de Potage de légumes verts du panier
#  </span>
#  </button>
#  <div aria-live="assertive" class="pi-Quantity-region js-Quantity-region" data-aria-label="Quantité de Potage de légumes verts dans le panier." role="alert">
#  <span class="js-Quantity-value">0</span>
#  </div>
#  <button class="pi-Quantity-button js-Quantity-more" data-id="more-000000000000013659" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="15" viewbox="0 0 15 15" width="15" xmlns="http://www.w3.org/2000/svg">
#  <path d="M6.5 6.538V.75a.75.75 0 111.5 0v5.788h5.788a.75.75 0 010 1.5H8v5.75a.75.75 0 01-1.5 0v-5.75H.75a.75.75 0 010-1.5H6.5z" fill-rule="nonzero"></path>
#  </svg>
#  <span class="sr-only">
#  Ajouter 1 quantité de Potage de légumes verts au panier
#  </span>
#  </button>
#  </div>
#  <input class="pi-AddToCart-quantityField js-AddToCart-quantityField" data-available="1.0" maxlength="2" name="Quantity" type="hidden" value="1.0"/>
#  </form>
#  <div class="pi-AddToCart-tooltipWrapper js-AddToCart-tooltipPlaceholder"></div>
#  </div>
#  </div>,
#  <div class="pi-ProductCard js-ProductCard">
#  <a class="pi-ProductCard-link js-gtm-ProductCard-link" href="/produits/legumes-pour-wok-legumes-asiatiques-000000000000087403.html">
#  <div class="pi-ProductCard-topContainer js-ProductCard-topContainer">
#  <div class="pi-ProductCardTag-placeholder">
#  </div>
#  <div class="pi-ProductCard-imageContainer">
#  <img alt="LEGUMES POUR WOK (MEL LEGUME ASIATIQUE)" class="pi-ProductCard-image pi-ProductCard-imageHover lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dw48f48f29/produits/legumes/edition/000000000000087403_E1.jpg?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  <img alt="LEGUMES POUR WOK (MEL LEGUME ASIATIQUE)" class="pi-ProductCard-image pi-ProductCard-imageInitial lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dw1b8eb4eb/produits/000000000000087403_P.png?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  </div>
#  </div>
#  <div class="pi-ProductCard-bottomContainer">
#  <div class="pi-ProductCard-labelWrapper">
#  </div>
#  <div class="pi-ProductCard-reviewWrapper">
#  <div class="pi-Rating null">
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <span class="pi-Rating-rate" style="width:88.51%;background-image: url('/on/demandware.static/Sites-picard-Site/-/default/dw5a2139ce/assets/images/reviews/star-full.png')"></span>
#  <span class="sr-only">4.4255 sur 5</span>
#  </div>
#  </div>
#  <h3 class="pi-ProductCard-name">
#  Légumes asiatiques pour wok
#  </h3>
#  <div class="pi-ProductCard-weight">
#  <span>le sachet de 600 g</span>
#  </div>
#  <div class="pi-ProductCardPrice pi-ProductCardPrice--light">
#  <div class="pi-ProductCardPrice-block">
#  <div class="pi-ProductCardPrice-kiloPrice">
#  <span class="sr-only">Prix au kilo</span>
#  4,50 €/kg
#  </div>
#  <div class="pi-ProductCardPrice-salesPrice">
#  <span class="sr-only">Prix soldé</span>
#  2,70 €
#  </div>
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="pi-ProductCard-actions">
#  <form action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-AddToCartProduct" class="pi-AddToCart js-AddToCart" data-delete-action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-DeleteProductLineItem" data-icon-msg="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#check" data-icon-tooltip="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#close" data-pid="000000000000087403" data-show-msg="false" data-text-msg="dans votre panier !" data-text-tooltip="La quantité maximale est atteinte sur ce produit." id="dwfrm_product_addtocart_d0jwtfhdiqkf" method="post">
#  <input name="cartAction" type="hidden" value="add"/>
#  <input class="js-AddToCart-pid" name="pid" type="hidden" value="000000000000087403"/>
#  <input name="sourcePage" type="hidden" value="null"/>
#  <button class="pi-AddToCart-button pi-ProductCard-btn pi-ProductCard-btn--blue u-Button js-AddToCart-button" data-isdisabled="false" data-showqty="" disabled="">
#  Ajouter au panier
#  <svg aria-hidden="true" class="u-Icon u-Button-icon" focusable="false" height="25" viewbox="0 0 31 25" width="31">
#  <use href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket" xlink:href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket"></use>
#  </svg>
#  </button>
#  <div class="pi-Quantity js-Quantity pi-AddToCart-quantity null" data-pid="000000000000087403">
#  <button class="pi-Quantity-button js-Quantity-less" data-id="less-000000000000087403" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="3" viewbox="0 0 14.5 1.5" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M.8 1.5c-.4 0-.8-.3-.8-.8s.3-.8.8-.8h13c.4 0 .8.3.8.8s-.3.8-.8.8H.8z"></path>
#  </svg>
#  <span class="sr-only">
#  Retirer 1 quantité de Légumes asiatiques pour wok du panier
#  </span>
#  </button>
#  <div aria-live="assertive" class="pi-Quantity-region js-Quantity-region" data-aria-label="Quantité de Légumes asiatiques pour wok dans le panier." role="alert">
#  <span class="js-Quantity-value">0</span>
#  </div>
#  <button class="pi-Quantity-button js-Quantity-more" data-id="more-000000000000087403" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="15" viewbox="0 0 15 15" width="15" xmlns="http://www.w3.org/2000/svg">
#  <path d="M6.5 6.538V.75a.75.75 0 111.5 0v5.788h5.788a.75.75 0 010 1.5H8v5.75a.75.75 0 01-1.5 0v-5.75H.75a.75.75 0 010-1.5H6.5z" fill-rule="nonzero"></path>
#  </svg>
#  <span class="sr-only">
#  Ajouter 1 quantité de Légumes asiatiques pour wok au panier
#  </span>
#  </button>
#  </div>
#  <input class="pi-AddToCart-quantityField js-AddToCart-quantityField" data-available="1.0" maxlength="2" name="Quantity" type="hidden" value="1.0"/>
#  </form>
#  <div class="pi-AddToCart-tooltipWrapper js-AddToCart-tooltipPlaceholder"></div>
#  </div>
#  </div>,
#  <div class="pi-ProductCard js-ProductCard">
#  <a class="pi-ProductCard-link js-gtm-ProductCard-link" href="/produits/melange-fruits-rouges-000000000000068209.html">
#  <div class="pi-ProductCard-topContainer js-ProductCard-topContainer">
#  <div class="pi-ProductCardTag-placeholder">
#  <style>
#  .pi-ProductCard--a4c23905cf64a605aa941bdc22 {
#  color: #e94f5e;
#  }
#  .pi-ProductCard--a4c23905cf64a605aa941bdc22:before {
#  background-color: #e94f5e;
#  }
#  .pi-ProductCard--a4c23905cf64a605aa941bdc22:after {
#  border-color: #e94f5e transparent transparent #e94f5e;
#  }
#  </style>
#  <div class="pi-ProductCardTag pi-ProductCardTag--card pi-ProductCard--a4c23905cf64a605aa941bdc22 js-ProductCardTag">
#  <svg aria-hidden="true" class="u-Icon pi-ProductCardTag-icon" focusable="false" height="60" viewbox="0 0 60 60" width="60">
#  <use href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#fidelity-offer" xlink:href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#fidelity-offer"></use>
#  </svg>
#  <div class="pi-ProductCardTag-title">
#  -0,50€ avec la carte
#  </div>
#  <button class="pi-ProductCardTag-overlayArrow">
#  <svg aria-hidden="true" class="u-Icon pi-ProductCardTag-overlayArrowIcon" focusable="false" height="9" viewbox="0 0 16 9" width="16">
#  <use href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#arrow" xlink:href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#arrow"></use>
#  </svg>
#  </button>
#  <div class="pi-ProductCardTag-overlay pi-ProductCardTag-overlay">
#  Du 19 février au 03 mars 2024, bénéficiez de réduction sur une sélection de produits avec la carte Picard&amp;Nous.
#  </div>
#  </div>
#  </div>
#  <div class="pi-ProductCard-imageContainer">
#  <img alt="NEW COCKTAIL FRUIT ROUGE" class="pi-ProductCard-image pi-ProductCard-imageHover lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dw62be2655/produits/000000000000068209_E.jpg?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  <img alt="NEW COCKTAIL FRUIT ROUGE" class="pi-ProductCard-image pi-ProductCard-imageInitial lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dwee208bb4/produits/000000000000068209_P.png?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  </div>
#  </div>
#  <div class="pi-ProductCard-bottomContainer">
#  <div class="pi-ProductCard-labelWrapper">
#  </div>
#  <div class="pi-ProductCard-reviewWrapper">
#  <div class="pi-Rating null">
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <span class="pi-Rating-rate" style="width:77.33399999999999%;background-image: url('/on/demandware.static/Sites-picard-Site/-/default/dw5a2139ce/assets/images/reviews/star-full.png')"></span>
#  <span class="sr-only">3.8667 sur 5</span>
#  </div>
#  </div>
#  <h3 class="pi-ProductCard-name">
#  Cocktail de fruits rouges
#  </h3>
#  <div class="pi-ProductCard-weight">
#  <span>le sachet de 450 g</span>
#  </div>
#  <div class="pi-ProductCardPrice pi-ProductCardPrice--fid">
#  <div class="pi-ProductCardPrice-block">
#  <div class="pi-ProductCardPrice-kiloPrice">
#  <span class="sr-only">Prix au kilo</span>
#  11,08 €/kg
#  </div>
#  <div class="pi-ProductCardPrice-salesPrice">
#  <span class="sr-only">Prix soldé</span>
#  4,99 €
#  </div>
#  </div>
#  <div class="pi-ProductCardPrice-block pi-ProductCardPrice-block--fidelite">
#  <style type="text/css">
#  .pi-ProductOffer-pricee94f5e {
#  color: #e94f5e;
#  }
#  </style>
#  <div class="pi-ProductCardPrice-kiloPrice pi-ProductOffer-pricee94f5e">
#  <span class="sr-only">Prix au kilo carte fidélité</span>
#  9,97 €/kg
#  </div>
#  <div class="pi-ProductCardPrice-salesPrice pi-ProductOffer-pricee94f5e">
#  <span class="sr-only">Prix soldé carte fidélité</span>
#  4,49 €
#  </div>
#  <div class="pi-ProductCardPrice-standardPrice">
#  <span class="sr-only">Prix soldé carte fidélité</span>
#  prix carte
#  </div>
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="pi-ProductCard-actions">
#  <form action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-AddToCartProduct" class="pi-AddToCart js-AddToCart" data-delete-action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-DeleteProductLineItem" data-icon-msg="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#check" data-icon-tooltip="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#close" data-pid="000000000000068209" data-show-msg="false" data-text-msg="dans votre panier !" data-text-tooltip="La quantité maximale est atteinte sur ce produit." id="dwfrm_product_addtocart_d0hwdjxpumeg" method="post">
#  <input name="cartAction" type="hidden" value="add"/>
#  <input class="js-AddToCart-pid" name="pid" type="hidden" value="000000000000068209"/>
#  <input name="sourcePage" type="hidden" value="null"/>
#  <button class="pi-AddToCart-button pi-ProductCard-btn pi-ProductCard-btn--blue u-Button js-AddToCart-button" data-isdisabled="false" data-showqty="" disabled="">
#  Ajouter au panier
#  <svg aria-hidden="true" class="u-Icon u-Button-icon" focusable="false" height="25" viewbox="0 0 31 25" width="31">
#  <use href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket" xlink:href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket"></use>
#  </svg>
#  </button>
#  <div class="pi-Quantity js-Quantity pi-AddToCart-quantity null" data-pid="000000000000068209">
#  <button class="pi-Quantity-button js-Quantity-less" data-id="less-000000000000068209" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="3" viewbox="0 0 14.5 1.5" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M.8 1.5c-.4 0-.8-.3-.8-.8s.3-.8.8-.8h13c.4 0 .8.3.8.8s-.3.8-.8.8H.8z"></path>
#  </svg>
#  <span class="sr-only">
#  Retirer 1 quantité de Cocktail de fruits rouges du panier
#  </span>
#  </button>
#  <div aria-live="assertive" class="pi-Quantity-region js-Quantity-region" data-aria-label="Quantité de Cocktail de fruits rouges dans le panier." role="alert">
#  <span class="js-Quantity-value">0</span>
#  </div>
#  <button class="pi-Quantity-button js-Quantity-more" data-id="more-000000000000068209" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="15" viewbox="0 0 15 15" width="15" xmlns="http://www.w3.org/2000/svg">
#  <path d="M6.5 6.538V.75a.75.75 0 111.5 0v5.788h5.788a.75.75 0 010 1.5H8v5.75a.75.75 0 01-1.5 0v-5.75H.75a.75.75 0 010-1.5H6.5z" fill-rule="nonzero"></path>
#  </svg>
#  <span class="sr-only">
#  Ajouter 1 quantité de Cocktail de fruits rouges au panier
#  </span>
#  </button>
#  </div>
#  <input class="pi-AddToCart-quantityField js-AddToCart-quantityField" data-available="1.0" maxlength="2" name="Quantity" type="hidden" value="1.0"/>
#  </form>
#  <div class="pi-AddToCart-tooltipWrapper js-AddToCart-tooltipPlaceholder"></div>
#  </div>
#  </div>,
#  <div class="pi-ProductCard js-ProductCard">
#  <a class="pi-ProductCard-link js-gtm-ProductCard-link" href="/produits/legumes-pour-potage-000000000000000222.html">
#  <div class="pi-ProductCard-topContainer js-ProductCard-topContainer">
#  <div class="pi-ProductCardTag-placeholder">
#  </div>
#  <div class="pi-ProductCard-imageContainer">
#  <img alt="1K LEGUMES POTAGES" class="pi-ProductCard-image pi-ProductCard-imageHover lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dw4f0fd3a5/produits/legumes/edition/000000000000000222_E.jpg?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  <img alt="1K LEGUMES POTAGES" class="pi-ProductCard-image pi-ProductCard-imageInitial lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dwb84bce3d/produits/000000000000000222_P.png?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  </div>
#  </div>
#  <div class="pi-ProductCard-bottomContainer">
#  <div class="pi-ProductCard-labelWrapper">
#  </div>
#  <div class="pi-ProductCard-reviewWrapper">
#  <div class="pi-Rating null">
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <span class="pi-Rating-rate" style="width:89.876%;background-image: url('/on/demandware.static/Sites-picard-Site/-/default/dw5a2139ce/assets/images/reviews/star-full.png')"></span>
#  <span class="sr-only">4.4938 sur 5</span>
#  </div>
#  </div>
#  <h3 class="pi-ProductCard-name">
#  Légumes pour potage
#  </h3>
#  <div class="pi-ProductCard-weight">
#  <span>le sachet de 1 kg</span>
#  </div>
#  <div class="pi-ProductCardPrice pi-ProductCardPrice--light">
#  <div class="pi-ProductCardPrice-block">
#  <div class="pi-ProductCardPrice-kiloPrice">
#  <span class="sr-only">Prix au kilo</span>
#  2,50 €/kg
#  </div>
#  <div class="pi-ProductCardPrice-salesPrice">
#  <span class="sr-only">Prix soldé</span>
#  2,50 €
#  </div>
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="pi-ProductCard-actions">
#  <form action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-AddToCartProduct" class="pi-AddToCart js-AddToCart" data-delete-action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-DeleteProductLineItem" data-icon-msg="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#check" data-icon-tooltip="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#close" data-pid="000000000000000222" data-show-msg="false" data-text-msg="dans votre panier !" data-text-tooltip="La quantité maximale est atteinte sur ce produit." id="dwfrm_product_addtocart_d0lstyidmuid" method="post">
#  <input name="cartAction" type="hidden" value="add"/>
#  <input class="js-AddToCart-pid" name="pid" type="hidden" value="000000000000000222"/>
#  <input name="sourcePage" type="hidden" value="null"/>
#  <button class="pi-AddToCart-button pi-ProductCard-btn pi-ProductCard-btn--blue u-Button js-AddToCart-button" data-isdisabled="false" data-showqty="" disabled="">
#  Ajouter au panier
#  <svg aria-hidden="true" class="u-Icon u-Button-icon" focusable="false" height="25" viewbox="0 0 31 25" width="31">
#  <use href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket" xlink:href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket"></use>
#  </svg>
#  </button>
#  <div class="pi-Quantity js-Quantity pi-AddToCart-quantity null" data-pid="000000000000000222">
#  <button class="pi-Quantity-button js-Quantity-less" data-id="less-000000000000000222" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="3" viewbox="0 0 14.5 1.5" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M.8 1.5c-.4 0-.8-.3-.8-.8s.3-.8.8-.8h13c.4 0 .8.3.8.8s-.3.8-.8.8H.8z"></path>
#  </svg>
#  <span class="sr-only">
#  Retirer 1 quantité de Légumes pour potage du panier
#  </span>
#  </button>
#  <div aria-live="assertive" class="pi-Quantity-region js-Quantity-region" data-aria-label="Quantité de Légumes pour potage dans le panier." role="alert">
#  <span class="js-Quantity-value">0</span>
#  </div>
#  <button class="pi-Quantity-button js-Quantity-more" data-id="more-000000000000000222" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="15" viewbox="0 0 15 15" width="15" xmlns="http://www.w3.org/2000/svg">
#  <path d="M6.5 6.538V.75a.75.75 0 111.5 0v5.788h5.788a.75.75 0 010 1.5H8v5.75a.75.75 0 01-1.5 0v-5.75H.75a.75.75 0 010-1.5H6.5z" fill-rule="nonzero"></path>
#  </svg>
#  <span class="sr-only">
#  Ajouter 1 quantité de Légumes pour potage au panier
#  </span>
#  </button>
#  </div>
#  <input class="pi-AddToCart-quantityField js-AddToCart-quantityField" data-available="1.0" maxlength="2" name="Quantity" type="hidden" value="1.0"/>
#  </form>
#  <div class="pi-AddToCart-tooltipWrapper js-AddToCart-tooltipPlaceholder"></div>
#  </div>
#  </div>,
#  <div class="pi-ProductCard js-ProductCard">
#  <a class="pi-ProductCard-link js-gtm-ProductCard-link" href="/produits/pommes-noisettes-000000000000006245.html">
#  <div class="pi-ProductCard-topContainer js-ProductCard-topContainer">
#  <div class="pi-ProductCardTag-placeholder">
#  <style>
#  .pi-ProductCard--4cd1b74388552b7c436f827fca {
#  color: #2d4a9a;
#  }
#  .pi-ProductCard--4cd1b74388552b7c436f827fca:before {
#  background-color: #2d4a9a;
#  }
#  .pi-ProductCard--4cd1b74388552b7c436f827fca:after {
#  border-color: #2d4a9a transparent transparent #2d4a9a;
#  }
#  </style>
#  <div class="pi-ProductCardTag pi-ProductCard--4cd1b74388552b7c436f827fca">
#  <img alt="Meilleures ventes" class="pi-ProductCardTag-icon pi-ProductCardTag-icon--custom" src="/on/demandware.static/-/Sites/default/dw23a51651/images/Promo/promo_ventes.png"/>
#  <div class="pi-ProductCardTag-title">
#  Meilleures ventes
#  </div>
#  </div>
#  </div>
#  <div class="pi-ProductCard-imageContainer">
#  <img alt="1K POMMES NOISETTES" class="pi-ProductCard-image pi-ProductCard-imageHover lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dw91a06b8b/produits/000000000000006245_E2.jpg?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  <img alt="1K POMMES NOISETTES" class="pi-ProductCard-image pi-ProductCard-imageInitial lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dw07eea3c9/produits/000000000000006245_P.png?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  </div>
#  </div>
#  <div class="pi-ProductCard-bottomContainer">
#  <div class="pi-ProductCard-labelWrapper">
#  </div>
#  <div class="pi-ProductCard-reviewWrapper">
#  <div class="pi-Rating null">
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <span class="pi-Rating-rate" style="width:91.94200000000001%;background-image: url('/on/demandware.static/Sites-picard-Site/-/default/dw5a2139ce/assets/images/reviews/star-full.png')"></span>
#  <span class="sr-only">4.5971 sur 5</span>
#  </div>
#  </div>
#  <h3 class="pi-ProductCard-name">
#  Pommes noisettes
#  </h3>
#  <div class="pi-ProductCard-weight">
#  <span>le sachet de 1 kg</span>
#  </div>
#  <div class="pi-ProductCardPrice pi-ProductCardPrice--promo">
#  <div class="pi-ProductCardPrice-block">
#  <div class="pi-ProductCardPrice-kiloPrice">
#  <span class="sr-only">Prix au kilo</span>
#  1,99 €/kg
#  </div>
#  <div class="pi-ProductCardPrice-salesPrice">
#  <span class="sr-only">Prix soldé</span>
#  1,99 €
#  </div>
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="pi-ProductCard-actions">
#  <form action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-AddToCartProduct" class="pi-AddToCart js-AddToCart" data-delete-action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-DeleteProductLineItem" data-icon-msg="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#check" data-icon-tooltip="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#close" data-pid="000000000000006245" data-show-msg="false" data-text-msg="dans votre panier !" data-text-tooltip="La quantité maximale est atteinte sur ce produit." id="dwfrm_product_addtocart_d0addnmtahgx" method="post">
#  <input name="cartAction" type="hidden" value="add"/>
#  <input class="js-AddToCart-pid" name="pid" type="hidden" value="000000000000006245"/>
#  <input name="sourcePage" type="hidden" value="null"/>
#  <button class="pi-AddToCart-button pi-ProductCard-btn pi-ProductCard-btn--blue u-Button js-AddToCart-button" data-isdisabled="false" data-showqty="" disabled="">
#  Ajouter au panier
#  <svg aria-hidden="true" class="u-Icon u-Button-icon" focusable="false" height="25" viewbox="0 0 31 25" width="31">
#  <use href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket" xlink:href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket"></use>
#  </svg>
#  </button>
#  <div class="pi-Quantity js-Quantity pi-AddToCart-quantity null" data-pid="000000000000006245">
#  <button class="pi-Quantity-button js-Quantity-less" data-id="less-000000000000006245" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="3" viewbox="0 0 14.5 1.5" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M.8 1.5c-.4 0-.8-.3-.8-.8s.3-.8.8-.8h13c.4 0 .8.3.8.8s-.3.8-.8.8H.8z"></path>
#  </svg>
#  <span class="sr-only">
#  Retirer 1 quantité de Pommes noisettes du panier
#  </span>
#  </button>
#  <div aria-live="assertive" class="pi-Quantity-region js-Quantity-region" data-aria-label="Quantité de Pommes noisettes dans le panier." role="alert">
#  <span class="js-Quantity-value">0</span>
#  </div>
#  <button class="pi-Quantity-button js-Quantity-more" data-id="more-000000000000006245" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="15" viewbox="0 0 15 15" width="15" xmlns="http://www.w3.org/2000/svg">
#  <path d="M6.5 6.538V.75a.75.75 0 111.5 0v5.788h5.788a.75.75 0 010 1.5H8v5.75a.75.75 0 01-1.5 0v-5.75H.75a.75.75 0 010-1.5H6.5z" fill-rule="nonzero"></path>
#  </svg>
#  <span class="sr-only">
#  Ajouter 1 quantité de Pommes noisettes au panier
#  </span>
#  </button>
#  </div>
#  <input class="pi-AddToCart-quantityField js-AddToCart-quantityField" data-available="1.0" maxlength="2" name="Quantity" type="hidden" value="1.0"/>
#  </form>
#  <div class="pi-AddToCart-tooltipWrapper js-AddToCart-tooltipPlaceholder"></div>
#  </div>
#  </div>,
#  <div class="pi-ProductCard js-ProductCard">
#  <a class="pi-ProductCard-link js-gtm-ProductCard-link" href="/produits/risotto-asperges-vertes-000000000000081459.html">
#  <div class="pi-ProductCard-topContainer js-ProductCard-topContainer">
#  <div class="pi-ProductCardTag-placeholder">
#  </div>
#  <div class="pi-ProductCard-imageContainer">
#  <img alt="500G RISOTTO AUX ASPERGES" class="pi-ProductCard-image pi-ProductCard-imageHover lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dw0241a4f2/produits/000000000000081459_E.jpg?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  <img alt="500G RISOTTO AUX ASPERGES" class="pi-ProductCard-image pi-ProductCard-imageInitial lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dw4259368b/produits/000000000000081459_P.png?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  </div>
#  </div>
#  <div class="pi-ProductCard-bottomContainer">
#  <div class="pi-ProductCard-labelWrapper">
#  </div>
#  <div class="pi-ProductCard-reviewWrapper">
#  <div class="pi-Rating null">
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <span class="pi-Rating-rate" style="width:81.228%;background-image: url('/on/demandware.static/Sites-picard-Site/-/default/dw5a2139ce/assets/images/reviews/star-full.png')"></span>
#  <span class="sr-only">4.0614 sur 5</span>
#  </div>
#  </div>
#  <h3 class="pi-ProductCard-name">
#  Risotto aux asperges vertes
#  </h3>
#  <div class="pi-ProductCard-weight">
#  <span>le sachet de 500 g</span>
#  </div>
#  <div class="pi-ProductCardPrice pi-ProductCardPrice--light">
#  <div class="pi-ProductCardPrice-block">
#  <div class="pi-ProductCardPrice-kiloPrice">
#  <span class="sr-only">Prix au kilo</span>
#  9,00 €/kg
#  </div>
#  <div class="pi-ProductCardPrice-salesPrice">
#  <span class="sr-only">Prix soldé</span>
#  4,50 €
#  </div>
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="pi-ProductCard-actions">
#  <form action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-AddToCartProduct" class="pi-AddToCart js-AddToCart" data-delete-action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-DeleteProductLineItem" data-icon-msg="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#check" data-icon-tooltip="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#close" data-pid="000000000000081459" data-show-msg="false" data-text-msg="dans votre panier !" data-text-tooltip="La quantité maximale est atteinte sur ce produit." id="dwfrm_product_addtocart_d0ptwiljgrmg" method="post">
#  <input name="cartAction" type="hidden" value="add"/>
#  <input class="js-AddToCart-pid" name="pid" type="hidden" value="000000000000081459"/>
#  <input name="sourcePage" type="hidden" value="null"/>
#  <button class="pi-AddToCart-button pi-ProductCard-btn pi-ProductCard-btn--blue u-Button js-AddToCart-button" data-isdisabled="false" data-showqty="" disabled="">
#  Ajouter au panier
#  <svg aria-hidden="true" class="u-Icon u-Button-icon" focusable="false" height="25" viewbox="0 0 31 25" width="31">
#  <use href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket" xlink:href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket"></use>
#  </svg>
#  </button>
#  <div class="pi-Quantity js-Quantity pi-AddToCart-quantity null" data-pid="000000000000081459">
#  <button class="pi-Quantity-button js-Quantity-less" data-id="less-000000000000081459" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="3" viewbox="0 0 14.5 1.5" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M.8 1.5c-.4 0-.8-.3-.8-.8s.3-.8.8-.8h13c.4 0 .8.3.8.8s-.3.8-.8.8H.8z"></path>
#  </svg>
#  <span class="sr-only">
#  Retirer 1 quantité de Risotto aux asperges vertes du panier
#  </span>
#  </button>
#  <div aria-live="assertive" class="pi-Quantity-region js-Quantity-region" data-aria-label="Quantité de Risotto aux asperges vertes dans le panier." role="alert">
#  <span class="js-Quantity-value">0</span>
#  </div>
#  <button class="pi-Quantity-button js-Quantity-more" data-id="more-000000000000081459" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="15" viewbox="0 0 15 15" width="15" xmlns="http://www.w3.org/2000/svg">
#  <path d="M6.5 6.538V.75a.75.75 0 111.5 0v5.788h5.788a.75.75 0 010 1.5H8v5.75a.75.75 0 01-1.5 0v-5.75H.75a.75.75 0 010-1.5H6.5z" fill-rule="nonzero"></path>
#  </svg>
#  <span class="sr-only">
#  Ajouter 1 quantité de Risotto aux asperges vertes au panier
#  </span>
#  </button>
#  </div>
#  <input class="pi-AddToCart-quantityField js-AddToCart-quantityField" data-available="1.0" maxlength="2" name="Quantity" type="hidden" value="1.0"/>
#  </form>
#  <div class="pi-AddToCart-tooltipWrapper js-AddToCart-tooltipPlaceholder"></div>
#  </div>
#  </div>,
#  <div class="pi-ProductCard js-ProductCard">
#  <a class="pi-ProductCard-link js-gtm-ProductCard-link" href="/produits/poelee-legumes-grilles-courgette-aubergine-000000000000075770.html">
#  <div class="pi-ProductCard-topContainer js-ProductCard-topContainer">
#  <div class="pi-ProductCardTag-placeholder">
#  <style>
#  .pi-ProductCard--4cd1b74388552b7c436f827fca {
#  color: #2d4a9a;
#  }
#  .pi-ProductCard--4cd1b74388552b7c436f827fca:before {
#  background-color: #2d4a9a;
#  }
#  .pi-ProductCard--4cd1b74388552b7c436f827fca:after {
#  border-color: #2d4a9a transparent transparent #2d4a9a;
#  }
#  </style>
#  <div class="pi-ProductCardTag pi-ProductCard--4cd1b74388552b7c436f827fca">
#  <img alt="Meilleures ventes" class="pi-ProductCardTag-icon pi-ProductCardTag-icon--custom" src="/on/demandware.static/-/Sites/default/dw23a51651/images/Promo/promo_ventes.png"/>
#  <div class="pi-ProductCardTag-title">
#  Meilleures ventes
#  </div>
#  </div>
#  </div>
#  <div class="pi-ProductCard-imageContainer">
#  <img alt="600G POELEE LEG GRILLES" class="pi-ProductCard-image pi-ProductCard-imageHover lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dwa055437e/produits/000000000000075770_E.jpg?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  <img alt="600G POELEE LEG GRILLES" class="pi-ProductCard-image pi-ProductCard-imageInitial lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dwb1810250/produits/000000000000075770_P.png?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  </div>
#  </div>
#  <div class="pi-ProductCard-bottomContainer">
#  <div class="pi-ProductCard-labelWrapper">
#  </div>
#  <div class="pi-ProductCard-reviewWrapper">
#  <div class="pi-Rating null">
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <span class="pi-Rating-rate" style="width:81.28999999999999%;background-image: url('/on/demandware.static/Sites-picard-Site/-/default/dw5a2139ce/assets/images/reviews/star-full.png')"></span>
#  <span class="sr-only">4.0645 sur 5</span>
#  </div>
#  </div>
#  <h3 class="pi-ProductCard-name">
#  Poêlée de légumes grillés courgette, aubergine
#  </h3>
#  <div class="pi-ProductCard-weight">
#  <span>le sachet de 600 g</span>
#  </div>
#  <div class="pi-ProductCardPrice pi-ProductCardPrice--promo">
#  <div class="pi-ProductCardPrice-block">
#  <div class="pi-ProductCardPrice-kiloPrice">
#  <span class="sr-only">Prix au kilo</span>
#  6,65 €/kg
#  </div>
#  <div class="pi-ProductCardPrice-salesPrice">
#  <span class="sr-only">Prix soldé</span>
#  3,99 €
#  </div>
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="pi-ProductCard-actions">
#  <form action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-AddToCartProduct" class="pi-AddToCart js-AddToCart" data-delete-action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-DeleteProductLineItem" data-icon-msg="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#check" data-icon-tooltip="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#close" data-pid="000000000000075770" data-show-msg="false" data-text-msg="dans votre panier !" data-text-tooltip="La quantité maximale est atteinte sur ce produit." id="dwfrm_product_addtocart_d0obleahzuay" method="post">
#  <input name="cartAction" type="hidden" value="add"/>
#  <input class="js-AddToCart-pid" name="pid" type="hidden" value="000000000000075770"/>
#  <input name="sourcePage" type="hidden" value="null"/>
#  <button class="pi-AddToCart-button pi-ProductCard-btn pi-ProductCard-btn--blue u-Button js-AddToCart-button" data-isdisabled="false" data-showqty="" disabled="">
#  Ajouter au panier
#  <svg aria-hidden="true" class="u-Icon u-Button-icon" focusable="false" height="25" viewbox="0 0 31 25" width="31">
#  <use href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket" xlink:href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket"></use>
#  </svg>
#  </button>
#  <div class="pi-Quantity js-Quantity pi-AddToCart-quantity null" data-pid="000000000000075770">
#  <button class="pi-Quantity-button js-Quantity-less" data-id="less-000000000000075770" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="3" viewbox="0 0 14.5 1.5" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M.8 1.5c-.4 0-.8-.3-.8-.8s.3-.8.8-.8h13c.4 0 .8.3.8.8s-.3.8-.8.8H.8z"></path>
#  </svg>
#  <span class="sr-only">
#  Retirer 1 quantité de Poêlée de légumes grillés courgette, aubergine du panier
#  </span>
#  </button>
#  <div aria-live="assertive" class="pi-Quantity-region js-Quantity-region" data-aria-label="Quantité de Poêlée de légumes grillés courgette, aubergine dans le panier." role="alert">
#  <span class="js-Quantity-value">0</span>
#  </div>
#  <button class="pi-Quantity-button js-Quantity-more" data-id="more-000000000000075770" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="15" viewbox="0 0 15 15" width="15" xmlns="http://www.w3.org/2000/svg">
#  <path d="M6.5 6.538V.75a.75.75 0 111.5 0v5.788h5.788a.75.75 0 010 1.5H8v5.75a.75.75 0 01-1.5 0v-5.75H.75a.75.75 0 010-1.5H6.5z" fill-rule="nonzero"></path>
#  </svg>
#  <span class="sr-only">
#  Ajouter 1 quantité de Poêlée de légumes grillés courgette, aubergine au panier
#  </span>
#  </button>
#  </div>
#  <input class="pi-AddToCart-quantityField js-AddToCart-quantityField" data-available="1.0" maxlength="2" name="Quantity" type="hidden" value="1.0"/>
#  </form>
#  <div class="pi-AddToCart-tooltipWrapper js-AddToCart-tooltipPlaceholder"></div>
#  </div>
#  </div>,
#  <div class="pi-ProductCard js-ProductCard">
#  <a class="pi-ProductCard-link js-gtm-ProductCard-link" href="/produits/salade-f.r.%2Fpeche-blanche-000000000000068090.html">
#  <div class="pi-ProductCard-topContainer js-ProductCard-topContainer">
#  <div class="pi-ProductCardTag-placeholder">
#  <style>
#  .pi-ProductCard--f13b0d95655881f33cb52173e2 {
#  color: #e94f5e;
#  }
#  .pi-ProductCard--f13b0d95655881f33cb52173e2:before {
#  background-color: #e94f5e;
#  }
#  .pi-ProductCard--f13b0d95655881f33cb52173e2:after {
#  border-color: #e94f5e transparent transparent #e94f5e;
#  }
#  </style>
#  <div class="pi-ProductCardTag pi-ProductCardTag--card pi-ProductCard--f13b0d95655881f33cb52173e2 js-ProductCardTag">
#  <svg aria-hidden="true" class="u-Icon pi-ProductCardTag-icon" focusable="false" height="60" viewbox="0 0 60 60" width="60">
#  <use href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#fidelity-offer" xlink:href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#fidelity-offer"></use>
#  </svg>
#  <div class="pi-ProductCardTag-title">
#  -0,70€ avec la carte
# ...
#  <input name="cartAction" type="hidden" value="add"/>
#  <input class="js-AddToCart-pid" name="pid" type="hidden" value="000000000000059449"/>
#  <input name="sourcePage" type="hidden" value="null"/>
#  <button class="pi-AddToCart-button pi-ProductCard-btn pi-ProductCard-btn--blue u-Button js-AddToCart-button" data-isdisabled="false" data-showqty="" disabled="">
#  Ajouter au panier
#  <svg aria-hidden="true" class="u-Icon u-Button-icon" focusable="false" height="25" viewbox="0 0 31 25" width="31">
#  <use href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket" xlink:href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket"></use>
#  </svg>
#  </button>
#  <div class="pi-Quantity js-Quantity pi-AddToCart-quantity null" data-pid="000000000000059449">
#  <button class="pi-Quantity-button js-Quantity-less" data-id="less-000000000000059449" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="3" viewbox="0 0 14.5 1.5" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M.8 1.5c-.4 0-.8-.3-.8-.8s.3-.8.8-.8h13c.4 0 .8.3.8.8s-.3.8-.8.8H.8z"></path>
#  </svg>
#  <span class="sr-only">
#  Retirer 1 quantité de Poêlée de pommes de terre grenaille du panier
#  </span>
#  </button>
#  <div aria-live="assertive" class="pi-Quantity-region js-Quantity-region" data-aria-label="Quantité de Poêlée de pommes de terre grenaille dans le panier." role="alert">
#  <span class="js-Quantity-value">0</span>
#  </div>
#  <button class="pi-Quantity-button js-Quantity-more" data-id="more-000000000000059449" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="15" viewbox="0 0 15 15" width="15" xmlns="http://www.w3.org/2000/svg">
#  <path d="M6.5 6.538V.75a.75.75 0 111.5 0v5.788h5.788a.75.75 0 010 1.5H8v5.75a.75.75 0 01-1.5 0v-5.75H.75a.75.75 0 010-1.5H6.5z" fill-rule="nonzero"></path>
#  </svg>
#  <span class="sr-only">
#  Ajouter 1 quantité de Poêlée de pommes de terre grenaille au panier
#  </span>
#  </button>
#  </div>
#  <input class="pi-AddToCart-quantityField js-AddToCart-quantityField" data-available="1.0" maxlength="2" name="Quantity" type="hidden" value="1.0"/>
#  </form>
#  <div class="pi-AddToCart-tooltipWrapper js-AddToCart-tooltipPlaceholder"></div>
#  </div>
#  </div>,
#  <div class="pi-ProductCard js-ProductCard">
#  <a class="pi-ProductCard-link js-gtm-ProductCard-link" href="/produits/potage-cuisine-9-legumes-bio-000000000000013485.html">
#  <div class="pi-ProductCard-topContainer js-ProductCard-topContainer">
#  <div class="pi-ProductCardTag-placeholder">
#  </div>
#  <div class="pi-ProductCard-imageContainer">
#  <img alt="POTAGE 9 LEG BIO CUISINE" class="pi-ProductCard-image pi-ProductCard-imageHover lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dwf3d01822/produits/000000000000013485_E.jpg?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  <img alt="POTAGE 9 LEG BIO CUISINE" class="pi-ProductCard-image pi-ProductCard-imageInitial lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dwc57bb4f0/produits/000000000000013485_P.png?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  </div>
#  </div>
#  <div class="pi-ProductCard-bottomContainer">
#  <div class="pi-ProductCard-labelWrapper">
#  <img alt="Bio" class="pi-ProductCard-label lazyload" data-src="/on/demandware.static/-/Sites-catalog-picard/default/dw81678a3a/pictoReglementaire/bio-card.png" src="..."/>
#  </div>
#  <div class="pi-ProductCard-reviewWrapper">
#  <div class="pi-Rating null">
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <span class="pi-Rating-rate" style="width:75.15799999999999%;background-image: url('/on/demandware.static/Sites-picard-Site/-/default/dw5a2139ce/assets/images/reviews/star-full.png')"></span>
#  <span class="sr-only">3.7579 sur 5</span>
#  </div>
#  </div>
#  <h3 class="pi-ProductCard-name">
#  Potage cuisiné aux 9 légumes bio
#  </h3>
#  <div class="pi-ProductCard-weight">
#  <span>le sachet de 1 kg</span>
#  </div>
#  <div class="pi-ProductCardPrice pi-ProductCardPrice--light">
#  <div class="pi-ProductCardPrice-block">
#  <div class="pi-ProductCardPrice-kiloPrice">
#  <span class="sr-only">Prix au kilo</span>
#  4,70 €/kg
#  </div>
#  <div class="pi-ProductCardPrice-salesPrice">
#  <span class="sr-only">Prix soldé</span>
#  4,70 €
#  </div>
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="pi-ProductCard-actions">
#  <form action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-AddToCartProduct" class="pi-AddToCart js-AddToCart" data-delete-action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-DeleteProductLineItem" data-icon-msg="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#check" data-icon-tooltip="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#close" data-pid="000000000000013485" data-show-msg="false" data-text-msg="dans votre panier !" data-text-tooltip="La quantité maximale est atteinte sur ce produit." id="dwfrm_product_addtocart_d0bjqsucmarp" method="post">
#  <input name="cartAction" type="hidden" value="add"/>
#  <input class="js-AddToCart-pid" name="pid" type="hidden" value="000000000000013485"/>
#  <input name="sourcePage" type="hidden" value="null"/>
#  <button class="pi-AddToCart-button pi-ProductCard-btn pi-ProductCard-btn--blue u-Button js-AddToCart-button" data-isdisabled="false" data-showqty="" disabled="">
#  Ajouter au panier
#  <svg aria-hidden="true" class="u-Icon u-Button-icon" focusable="false" height="25" viewbox="0 0 31 25" width="31">
#  <use href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket" xlink:href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket"></use>
#  </svg>
#  </button>
#  <div class="pi-Quantity js-Quantity pi-AddToCart-quantity null" data-pid="000000000000013485">
#  <button class="pi-Quantity-button js-Quantity-less" data-id="less-000000000000013485" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="3" viewbox="0 0 14.5 1.5" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M.8 1.5c-.4 0-.8-.3-.8-.8s.3-.8.8-.8h13c.4 0 .8.3.8.8s-.3.8-.8.8H.8z"></path>
#  </svg>
#  <span class="sr-only">
#  Retirer 1 quantité de Potage cuisiné aux 9 légumes bio du panier
#  </span>
#  </button>
#  <div aria-live="assertive" class="pi-Quantity-region js-Quantity-region" data-aria-label="Quantité de Potage cuisiné aux 9 légumes bio dans le panier." role="alert">
#  <span class="js-Quantity-value">0</span>
#  </div>
#  <button class="pi-Quantity-button js-Quantity-more" data-id="more-000000000000013485" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="15" viewbox="0 0 15 15" width="15" xmlns="http://www.w3.org/2000/svg">
#  <path d="M6.5 6.538V.75a.75.75 0 111.5 0v5.788h5.788a.75.75 0 010 1.5H8v5.75a.75.75 0 01-1.5 0v-5.75H.75a.75.75 0 010-1.5H6.5z" fill-rule="nonzero"></path>
#  </svg>
#  <span class="sr-only">
#  Ajouter 1 quantité de Potage cuisiné aux 9 légumes bio au panier
#  </span>
#  </button>
#  </div>
#  <input class="pi-AddToCart-quantityField js-AddToCart-quantityField" data-available="1.0" maxlength="2" name="Quantity" type="hidden" value="1.0"/>
#  </form>
#  <div class="pi-AddToCart-tooltipWrapper js-AddToCart-tooltipPlaceholder"></div>
#  </div>
#  </div>,
#  <div class="pi-ProductCard js-ProductCard">
#  <a class="pi-ProductCard-link js-gtm-ProductCard-link" href="/produits/allumettes-000000000000012551.html">
#  <div class="pi-ProductCard-topContainer js-ProductCard-topContainer">
#  <div class="pi-ProductCardTag-placeholder">
#  <style>
#  .pi-ProductCard--6735dff0f9f7987fddae8eb99e {
#  color: #0011ac;
#  }
#  .pi-ProductCard--6735dff0f9f7987fddae8eb99e:before {
#  background-color: #0011ac;
#  }
#  .pi-ProductCard--6735dff0f9f7987fddae8eb99e:after {
#  border-color: #0011ac transparent transparent #0011ac;
#  }
#  </style>
#  <div class="pi-ProductCardTag pi-ProductCard--6735dff0f9f7987fddae8eb99e js-ProductCardTag">
#  <img alt="Prix en baisse" class="pi-ProductCardTag-icon pi-ProductCardTag-icon--custom" src="/on/demandware.static/-/Sites/default/dwc6d5e27d/images/Promo/picto_250x250_prix.png"/>
#  <div class="pi-ProductCardTag-title">
#  Prix en baisse
#  </div>
#  <button class="pi-ProductCardTag-overlayArrow">
#  <svg aria-hidden="true" class="u-Icon pi-ProductCardTag-overlayArrowIcon" focusable="false" height="9" viewbox="0 0 16 9" width="16">
#  <use href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#arrow" xlink:href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#arrow"></use>
#  </svg>
#  </button>
#  <div class="pi-ProductCardTag-overlay pi-ProductCardTag-overlay">
#  Les prix de vente (et les prix au kilo) sont en baisse par rapport au tarif TTC (hors promotion, hors programme de fidélité Picard&amp;Nous) appliqué du 13 novembre 2023 au 31 décembre 2023 dans notre réseau (hors franchise) en France métropolitaine.
#  </div>
#  </div>
#  </div>
#  <div class="pi-ProductCard-imageContainer">
#  <img alt="1K POMMES ALLUMETTES" class="pi-ProductCard-image pi-ProductCard-imageHover lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dwa91ec43f/produits/000000000000012551_E.jpg?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  <img alt="1K POMMES ALLUMETTES" class="pi-ProductCard-image pi-ProductCard-imageInitial lazyload" data-src="https://www.picard.fr/dw/image/v2/AAHV_PRD/on/demandware.static/-/Sites-catalog-picard/default/dwb9db8aa3/produits/000000000000012551_P.png?sw=300&amp;sh=175&amp;q=30" src="..."/>
#  </div>
#  </div>
#  <div class="pi-ProductCard-bottomContainer">
#  <div class="pi-ProductCard-labelWrapper">
#  </div>
#  <div class="pi-ProductCard-reviewWrapper">
#  <div class="pi-Rating null">
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <img alt="" class="pi-Rating-img lazyload" data-src="/on/demandware.static/Sites-picard-Site/-/default/dw67685c60/assets/images/reviews/star-empty-small.png" height="15" src="..." width="15"/>
#  <span class="pi-Rating-rate" style="width:86.13799999999999%;background-image: url('/on/demandware.static/Sites-picard-Site/-/default/dw5a2139ce/assets/images/reviews/star-full.png')"></span>
#  <span class="sr-only">4.3069 sur 5</span>
#  </div>
#  </div>
#  <h3 class="pi-ProductCard-name">
#  Les Allumettes
#  </h3>
#  <div class="pi-ProductCard-weight">
#  <span>le sachet de 1 kg</span>
#  </div>
#  <div class="pi-ProductCardPrice pi-ProductCardPrice--promo">
#  <div class="pi-ProductCardPrice-block">
#  <div class="pi-ProductCardPrice-kiloPrice">
#  <span class="sr-only">Prix au kilo</span>
#  2,70 €/kg
#  </div>
#  <div class="pi-ProductCardPrice-salesPrice">
#  <span class="sr-only">Prix soldé</span>
#  2,70 €
#  </div>
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="pi-ProductCard-actions">
#  <form action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-AddToCartProduct" class="pi-AddToCart js-AddToCart" data-delete-action="https://www.picard.fr/on/demandware.store/Sites-picard-Site/fr_FR/Cart-DeleteProductLineItem" data-icon-msg="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#check" data-icon-tooltip="/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#close" data-pid="000000000000012551" data-show-msg="false" data-text-msg="dans votre panier !" data-text-tooltip="La quantité maximale est atteinte sur ce produit." id="dwfrm_product_addtocart_d0ebyaufatez" method="post">
#  <input name="cartAction" type="hidden" value="add"/>
#  <input class="js-AddToCart-pid" name="pid" type="hidden" value="000000000000012551"/>
#  <input name="sourcePage" type="hidden" value="null"/>
#  <button class="pi-AddToCart-button pi-ProductCard-btn pi-ProductCard-btn--blue u-Button js-AddToCart-button" data-isdisabled="false" data-showqty="" disabled="">
#  Ajouter au panier
#  <svg aria-hidden="true" class="u-Icon u-Button-icon" focusable="false" height="25" viewbox="0 0 31 25" width="31">
#  <use href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket" xlink:href="https://www.picard.fr/on/demandware.static/Sites-picard-Site/-/fr_FR/v1709225968154/assets/svg/sprite.symbol.svg#basket"></use>
#  </svg>
#  </button>
#  <div class="pi-Quantity js-Quantity pi-AddToCart-quantity null" data-pid="000000000000012551">
#  <button class="pi-Quantity-button js-Quantity-less" data-id="less-000000000000012551" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="3" viewbox="0 0 14.5 1.5" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M.8 1.5c-.4 0-.8-.3-.8-.8s.3-.8.8-.8h13c.4 0 .8.3.8.8s-.3.8-.8.8H.8z"></path>
#  </svg>
#  <span class="sr-only">
#  Retirer 1 quantité de Les Allumettes du panier
#  </span>
#  </button>
#  <div aria-live="assertive" class="pi-Quantity-region js-Quantity-region" data-aria-label="Quantité de Les Allumettes dans le panier." role="alert">
#  <span class="js-Quantity-value">0</span>
#  </div>
#  <button class="pi-Quantity-button js-Quantity-more" data-id="more-000000000000012551" type="button">
#  <svg aria-hidden="true" class="pi-Quantity-icon u-Icon" focusable="false" height="15" viewbox="0 0 15 15" width="15" xmlns="http://www.w3.org/2000/svg">
#  <path d="M6.5 6.538V.75a.75.75 0 111.5 0v5.788h5.788a.75.75 0 010 1.5H8v5.75a.75.75 0 01-1.5 0v-5.75H.75a.75.75 0 010-1.5H6.5z" fill-rule="nonzero"></path>
#  </svg>
#  <span class="sr-only">
#  Ajouter 1 quantité de Les Allumettes au panier
#  </span>
#  </button>
#  </div>
#  <input class="pi-AddToCart-quantityField js-AddToCart-quantityField" data-available="1.0" maxlength="2" name="Quantity" type="hidden" value="1.0"/>
#  </form>
#  <div class="pi-AddToCart-tooltipWrapper js-AddToCart-tooltipPlaceholder"></div>
#  </div>
#  </div>]

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

l_df = pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [11], in <module>
#       1 import ssl
#       2 ssl._create_default_https_context = ssl._create_unverified_context
# ----> 4 l_df = pd.read_html(url)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1109 validate_header_arg(header)
#    1111 io = stringify_path(io)
# -> 1113 return _parse(
#    1114     flavor=flavor,
#    1115     io=io,
#    1116     match=match,
#    1117     header=header,
#    1118     index_col=index_col,
#    1119     skiprows=skiprows,
#    1120     parse_dates=parse_dates,
#    1121     thousands=thousands,
#    1122     attrs=attrs,
#    1123     encoding=encoding,
#    1124     decimal=decimal,
#    1125     converters=converters,
#    1126     na_values=na_values,
#    1127     keep_default_na=keep_default_na,
#    1128     displayed_only=displayed_only,
#    1129 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/html.py:915, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     913 retained = None
#     914 for flav in flavor:
# --> 915     parser = _parser_dispatch(flav)
#     916     p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     918     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/html.py:864, in _parser_dispatch(flavor)
#     862 if flavor in ("bs4", "html5lib"):
#     863     if not _HAS_HTML5LIB:
# --> 864         raise ImportError("html5lib not found, please install it")
#     865     if not _HAS_BS4:
#     866         raise ImportError("BeautifulSoup4 (bs4) not found, please install it")
#
# ImportError: html5lib not found, please install it

# %%
l_df[0]
